# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenmech057/MLproject/blob/main/ML_model_with_two_input_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/bmi.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.shape
# Out:
# (500, 4)

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
df.isnull().count()
# Out:
# Gender    500
# Height    500
# Weight    500
# Index     500
# dtype: int64

# %%
x=df[["Height","Weight"]]
y=df["Gender"]
print(len(x))
print(len(y))
# Out:
# 500
# 500

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))
# Out:
# 400
# 400
# 100
# 100

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred =knn.predict(x_test)
print(len(y_test))
print(len(y_test))
# Out:
# 100
# 100

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.47

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred =lr.predict(x_test)
print(len(y_pred))
print(len(y_test))
# Out:
# 100
# 100

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)

# %%
print(acc)
# Out:
# 0.41

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)
print(len(y_pred))
print(len(y_test))
# Out:
# 100
# 100

# %%
acc=accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.59

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# test data
y_pred = rf.predict(x_test)
print(len(y_pred))
print(len(y_test))
# Out:
# 100
# 100

# %%
# validation
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.5

# %%
# adaptive boosting
from sklearn.ensemble import AdaBoostClassifier
ab=AdaBoostClassifier()
ab.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
# test data
y_pred = ab.predict(x_test)
print(len(y_pred))
print(len(y_test))
# Out:
# 100
# 100

# %%
# validation
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)

# %%
print(acc)
# Out:
# 0.49

# %%
from sklearn.svm import SVC
svc= SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
#  test data
y_pred = svc.predict(x_test)
print(len(y_pred))
print(len(y_test))
# Out:
# 100
# 100

# %%
# validtaion
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.5
